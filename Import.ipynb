# %%
from ClassFile import MultiFunc
MultiFunc.Subfields()
MultiFunc.OddEven()
MultiFunc.Elegible() 
MultiFunc.percentage()
MultiFunc.triangle()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# Enter a number:  56
# 56 is Even number
# Your Gender:  Female
# Your Age:  17
# Not Eligible
# Subject1:  67
# Subject2:  78
# Subject3:  45
# Subject4:  78
# Subject5:  45
# Total:  313
# Percentage:  62.6
# Height:  4
# Breadth:  5
# Area formula: (Height*Breadth)/2
# Area of Triangle:  10.0
# Height1:  7
# Height2:  6
# Breadth:  5
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle:  18
